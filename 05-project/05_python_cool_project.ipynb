# %% [markdown]
# # 05 Python Cool Project

# %%
# Uncomment the line below to install required packages
# !pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the AAPL.csv file
aapl_df = pd.read_csv('AAPL.csv')
aapl_df.head()

# %%
# Load the salary_guide_2023 (1).pkl file
salary_guide_df = pd.read_pickle('salary_guide_2023 (1).pkl')
salary_guide_df.head()
